# %%
import pandas as pd

# %%
lines = pd.read_csv('./lignes-par-type.csv', sep = ';')

# %%
lines.head()
# Out:
#               TYPE_LIGNE                                IDGAIA  CODE_LIGNE  \
# 0  Ligne proprement dite  470d9632-6665-11e3-afff-01f464e0362d      990000
# 1           Raccordement  471b8a6e-6665-11e3-afff-01f464e0362d      990306
# 2  Ligne proprement dite  471fcb52-6665-11e3-afff-01f464e0362d      899000
# 3  Ligne proprement dite  47174ff4-6665-11e3-afff-01f464e0362d      984000
# 4  Ligne proprement dite  470e41dc-6665-11e3-afff-01f464e0362d      120000
#
#                                          LIB_LIGNE  RG_TRONCON      PKD  \
# 0             Ligne de la grande ceinture de Paris           3  069+568
# 1              Raccordement de Versailles-Matelots           2  019+900
# 2  Ligne de St-Pierre-d'Albigny à Bourg-St-Maurice           1  001+768
# 3         Ligne de Quai-d'Orsay à Paris-Austerlitz           1    D+841
# 4           Ligne de Colmar-Central à Neuf-Brisach           1  000+370
#
#        PKF       X_D_L93       Y_D_L93       X_F_L93       Y_F_L93  X_D_WGS84  \
# ...

# %%
lines = lines.columns.str.lower()

# %%
lines = lines[[]]
