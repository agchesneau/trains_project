# %% [markdown]
# # Mid-Bootcamp project : does the region influences the reliability of a train line ?

# %% [markdown]
# ### Imports

# %%
# import getpass
# password = getpass.getpass()

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import re
import scipy.stats as st
import numpy as np
from opencage.geocoder import OpenCageGeocode
from geopy.distance import geodesic

# %% [markdown]
# ### Getting my file

# %%
reg1 = pd.read_csv('./regularite-mensuelle-intercites.csv', sep = ';')
reg1.columns = reg1.columns.str.lower()
reg1.columns = reg1.columns.str.replace(' ','_')
reg1.head()
# Out:
#          id     date               axe           départ           arrivée  \
# 0  INT_22_A  2014-01    Nord-Normandie  PARIS-ST-LAZARE         CHERBOURG
# 1  INT_35_A  2014-01    Nord-Normandie         LE-HAVRE   PARIS-ST-LAZARE
# 2  INT_16_A  2014-01    Nord-Normandie         MAUBEUGE        PARIS-NORD
# 3   INT_5_A  2014-01    Nord-Normandie             CAEN   PARIS-ST-LAZARE
# 4   INT_3_A  2014-01  Centre Sud-Ouest          ORLÉANS  PARIS-AUSTERLITZ
#
#    nombre_de_trains_programmés  nombre_de_trains_ayant_circulé  \
# 0                        173.0                           172.0
# 1                        364.0                           360.0
# 2                        306.0                           305.0
# 3                        193.0                           193.0
# 4                        355.0                           354.0
#
#    nombre_de_trains_annulés  nombre_de_trains_en_retard_à_l'arrivée  \
# 0                       1.0                                    14.0
# 1                       4.0                                    33.0
# 2                       1.0                                    18.0
# 3                       0.0                                    20.0
# 4                       1.0                                    40.0
#
#    taux_de_régularité  nombre_de_trains_à_l'heure_pour_un_train_en_retard  \
# 0                91.9                                               11.3
# 1                90.8                                                9.9
# 2                94.1                                               15.9
# 3                89.6                                                8.7
# 4                88.7                                                7.8
#
#                        empty
# 0  PARIS-ST-LAZARE:CHERBOURG
# 1   LE-HAVRE:PARIS-ST-LAZARE
# 2        MAUBEUGE:PARIS-NORD
# 3       CAEN:PARIS-ST-LAZARE
# 4   ORLÉANS:PARIS-AUSTERLITZ

# %% [markdown]
# ## Cleaning the data

# %%
reg1 = reg1.drop(['id'], axis = 1)

# %% [markdown]
# #### creating a month and a year column to potentially use to group by month/year

# %%
def split_month(row):
    x, y = row.split('-')
    return int(y)

reg1['month'] = reg1['date'].apply(split_month)

def split_year(row):
    x, y = row.split('-')
    return int(x)

reg1['year'] = reg1['date'].apply(split_year)

# %% [markdown]
# ### Renaming columns :

# %%
reg1.columns = ['date', 'axis', 'origin', 'destination', 'number_of_trains_scheduled',
       'number_of_trains_actual', 'number_of_train_canceled',
       'trains_late_at_destination', 'reliability',
       'number_of_trains_on_time_for_one_late_train', 'line', 'month', 'year']

# %% [markdown]
# ### Rearranging columns

# %%
reg1 = reg1[['date','month','year', 'axis', 'origin', 'destination', 'number_of_trains_scheduled',
       'number_of_trains_actual', 'number_of_train_canceled',
       'trains_late_at_destination', 'reliability',
       'number_of_trains_on_time_for_one_late_train', 'line']]

# %% [markdown]
# ### Creating a column of percentage of trains canceled for better comparison

# %%
reg1['percentage_trains_canceled'] = round(reg1['number_of_train_canceled']*100/reg1['number_of_trains_scheduled'], 2)

# %% [markdown]
# ### Creating a function to clean the names and applying it on the right columns

# %%
def cleaning_names(x):
    x = x.lower()
    x = re.sub('paris[-a-z]*', 'paris', x)
    x = re.sub('toulouse[-/a-z]*', 'toulouse', x)
    x = re.sub('le havre*', 'le-havre', x)
    x = re.sub('[-/a-z]*toulouse', 'toulouse', x)
    x = re.sub('lyon[-a-z]*', 'lyon', x)
    x = re.sub('cambrais/maubeuge', 'maubeuge', x)
    x = re.sub('(cahors/)?brive(/cahors)?', 'brive', x)
    x = re.sub('boulogne-ville', 'boulogne', x)
    x = re.sub('bourg-st-maurice/st-gervais', 'st-gervais', x)
    x = re.sub('(rodez/)?albi(/rodez)?', 'albi', x)
    x = re.sub('(cambrai/)?maubeuge(cambrai/)?', 'maubeuge', x)
    x = re.sub('briancon/nice-ville', 'nice', x)
    x = re.sub('é', 'e', x)
    x = re.sub('è', 'e', x)
    x = re.sub('î', 'i', x)
    x = re.sub(': ', ':', x)
    x = re.sub(' ', '-', x)
    x = re.sub('ç', 'c', x)
    return x
    
reg1['origin'] = reg1['origin'].apply(cleaning_names)
reg1['destination'] = reg1['destination'].apply(cleaning_names)
reg1['axis'] = reg1['axis'].apply(cleaning_names)
reg1['line'] = reg1['line'].apply(cleaning_names)
reg1.head(1)
# Out:
#       date  month  year            axis origin destination  \
# 0  2014-01      1  2014  nord-normandie  paris   cherbourg
#
#    number_of_trains_scheduled  number_of_trains_actual  \
# 0                       173.0                    172.0
#
#    number_of_train_canceled  trains_late_at_destination  reliability  \
# 0                       1.0                        14.0         91.9
#
#    number_of_trains_on_time_for_one_late_train             line  \
# 0                                         11.3  paris:cherbourg
#
#    percentage_trains_canceled
# 0                        0.58

# %% [markdown]
# # Adding high-speed trains

# %%
reg2 = pd.read_csv('./regularite-mensuelle-tgv-aqst.csv', sep = ';')
reg2.columns = reg2.columns.str.lower()
reg2.columns = reg2.columns.str.replace(' ','_')
reg2.head()
# Out:
#       date   service      gare_de_départ      gare_d'arrivée  \
# 0  2018-01  National           ANGOULEME  PARIS MONTPARNASSE
# 1  2018-01  National  PARIS MONTPARNASSE   LA ROCHELLE VILLE
# 2  2018-01  National  PARIS MONTPARNASSE               LAVAL
# 3  2018-01  National  PARIS MONTPARNASSE             QUIMPER
# 4  2018-01  National              RENNES      LYON PART DIEU
#
#    durée_moyenne_du_trajet  nombre_de_circulations_prévues  \
# 0                    125.0                           270.0
# 1                    166.0                           226.0
# 2                     84.0                           217.0
# 3                    220.0                           248.0
# 4                    233.0                            99.0
#
#    nombre_de_trains_annulés  commentaire_annulations  \
# 0                       4.0                      NaN
# 1                       0.0                      NaN
# 2                       0.0                      NaN
# 3                       1.0                      NaN
# 4                       0.0                      NaN
#
#    nombre_de_trains_en_retard_au_départ  \
# 0                                 135.0
# 1                                  21.0
# 2                                  32.0
# 3                                  37.0
# 4                                  23.0
#
#    retard_moyen_des_trains_en_retard_au_départ  ...  \
# 0                                     5.710123  ...
# 1                                     6.239683  ...
# 2                                    11.609375  ...
# 3                                     9.501351  ...
# 4                                     3.000000  ...
#
#    nombre_trains_en_retard_>_15min  \
# 0                             33.0
# 1                             11.0
# 2                             16.0
# 3                             26.0
# 4                              6.0
#
#    retard_moyen_trains_en_retard_>_15_(si_liaison_concurrencée_par_vol)  \
# 0                                           6.464975
# 1                                           2.938053
# 2                                           5.822811
# 3                                           7.548387
# 4                                           2.244613
#
#    nombre_trains_en_retard_>_30min  nombre_trains_en_retard_>_60min  \
# 0                              9.0                              0.0
# 1                              6.0                              1.0
# 2                              5.0                              2.0
# 3                             17.0                              7.0
# 4                              2.0                              1.0
#
#    prct_retard_pour_causes_externes prct_retard_pour_cause_infrastructure  \
# 0                         26.923077                             42.307692
# 1                         22.222222                             27.777778
# 2                         24.242424                             54.545455
# 3                         26.923077                             38.461538
# 4                          0.000000                             50.000000
#
#    prct_retard_pour_cause_gestion_trafic  \
# 0                               9.615385
# 1                              16.666667
# 2                               3.030303
# 3                              15.384615
# 4                              25.000000
#
#    prct_retard_pour_cause_matériel_roulant  \
# 0                                15.384615
# 1                                16.666667
# 2                                12.121212
# 3                                19.230769
# 4                                25.000000
#
#    prct_retard_pour_cause_gestion_en_gare_et_réutilisation_de_matériel  \
# 0                                           3.846154
# 1                                           5.555556
# 2                                           3.030303
# 3                                           0.000000
# 4                                           0.000000
#
#    prct_retard_pour_cause_prise_en_compte_voyageurs_(affluence,_gestions_psh,_correspondances)
# 0                                           1.923077
# 1                                          11.111111
# 2                                           3.030303
# 3                                           0.000000
# 4                                           0.000000
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Spliting dates

# %%
reg2['year'] = reg2['date'].apply(split_year)
reg2['month'] = reg2['date'].apply(split_month)

# %% [markdown]
# ## Making columns match

# %%
reg2.columns
# Out:
# Index(['date', 'service', 'gare_de_départ', 'gare_d'arrivée',
#        'durée_moyenne_du_trajet', 'nombre_de_circulations_prévues',
#        'nombre_de_trains_annulés', 'commentaire_annulations',
#        'nombre_de_trains_en_retard_au_départ',
#        'retard_moyen_des_trains_en_retard_au_départ',
#        'retard_moyen_de_tous_les_trains_au_départ',
#        'commentaire_retards_au_départ',
#        'nombre_de_trains_en_retard_à_l'arrivée',
#        'retard_moyen_des_trains_en_retard_à_l'arrivée',
#        'retard_moyen_de_tous_les_trains_à_l'arrivée',
#        'commentaire_retards_à_l'arrivée', 'nombre_trains_en_retard_>_15min',
#        'retard_moyen_trains_en_retard_>_15_(si_liaison_concurrencée_par_vol)',
#        'nombre_trains_en_retard_>_30min', 'nombre_trains_en_retard_>_60min',
#        'prct_retard_pour_causes_externes',
#        'prct_retard_pour_cause_infrastructure',
#        'prct_retard_pour_cause_gestion_trafic',
#        'prct_retard_pour_cause_matériel_roulant',
#        'prct_retard_pour_cause_gestion_en_gare_et_réutilisation_de_matériel',
#        'prct_retard_pour_cause_prise_en_compte_voyageurs_(affluence,_gestions_psh,_correspondances)',
#        'year', 'month'],
#       dtype='object')

# %%
reg2 = reg2[['date', 'month','year', 'service', 'gare_de_départ', "gare_d'arrivée",
       'nombre_de_circulations_prévues',
       'nombre_de_trains_annulés',
       "nombre_de_trains_en_retard_à_l'arrivée", 'durée_moyenne_du_trajet']]

# %%
reg1.columns
# Out:
# Index(['date', 'month', 'year', 'axis', 'origin', 'destination',
#        'number_of_trains_scheduled', 'number_of_trains_actual',
#        'number_of_train_canceled', 'trains_late_at_destination', 'reliability',
#        'number_of_trains_on_time_for_one_late_train', 'line',
#        'percentage_trains_canceled'],
#       dtype='object')

# %%
reg2.columns = ['date', 'month','year', 'axis', 'origin', "destination",
       'number_of_trains_scheduled',
       'number_of_train_canceled',
       "trains_late_at_destination", 'duration']

# %% [markdown]
# ## Cleaning names of cities

# %%
reg2["origin"].unique()
# Out:
# array(['ANGOULEME', 'PARIS MONTPARNASSE', 'RENNES', 'TOULOUSE MATABIAU',
#        'NANTES', 'PARIS EST', 'ARRAS', 'DOUAI', 'LILLE', 'PARIS NORD',
#        'PARIS VAUGIRARD', 'TOURCOING', 'ANNECY', 'AVIGNON TGV',
#        'BELLEGARDE (AIN)', 'LE CREUSOT MONTCEAU MONTCHANIN',
#        'LYON PART DIEU', 'MACON LOCHE', 'MARSEILLE ST CHARLES',
#        'PARIS LYON', 'VALENCE ALIXAN TGV', 'FRANCFORT',
#        'BORDEAUX ST JEAN', 'LA ROCHELLE VILLE', 'AIX EN PROVENCE TGV',
#        'MONTPELLIER', 'MULHOUSE VILLE', 'SAINT ETIENNE CHATEAUCREUX',
#        'MADRID', 'ANGERS SAINT LAUD', 'METZ', 'STRASBOURG', 'DUNKERQUE',
#        'BESANCON FRANCHE COMTE TGV', 'DIJON VILLE', 'GRENOBLE',
#        'NICE VILLE', 'TOULON', 'LE MANS', 'QUIMPER', 'ST MALO',
#        'ST PIERRE DES CORPS', 'TOURS', 'VANNES', 'NANCY',
#        'CHAMBERY CHALLES LES EAUX', 'MARNE LA VALLEE', 'NIMES',
#        'BARCELONA', 'GENEVE', 'ITALIE', 'LAUSANNE', 'BREST', 'LAVAL',
#        'POITIERS', 'REIMS', 'PERPIGNAN', 'STUTTGART', 'ZURICH'],
#       dtype=object)

# %%
def cleaning_names2(x):
    x = x.lower()
    x = re.sub('paris[ a-z]*', 'paris', x)
    x = re.sub('toulouse[ a-z]*', 'toulouse', x)
    x = re.sub('lyon[ a-z]*', 'lyon', x)
    x = re.sub(' tgv', '', x)
    x = re.sub('é', 'e', x)
    x = re.sub('è', 'e', x)
    x = re.sub('î', 'i', x)
    x = re.sub(' ', '-', x)
    x = re.sub('ç', 'c', x)
    return x


reg2['origin'] = reg2['origin'].apply(cleaning_names2)
reg2['destination'] = reg2['destination'].apply(cleaning_names2)

# %% [markdown]
# ### Just checking :

# %%
reg2['origin'].unique()
# Out:
# array(['angouleme', 'paris', 'rennes', 'toulouse', 'nantes', 'arras',
#        'douai', 'lille', 'tourcoing', 'annecy', 'avignon',
#        'bellegarde-(ain)', 'le-creusot-montceau-montchanin', 'lyon',
#        'macon-loche', 'marseille-st-charles', 'valence-alixan',
#        'francfort', 'bordeaux-st-jean', 'la-rochelle-ville',
#        'aix-en-provence', 'montpellier', 'mulhouse-ville',
#        'saint-etienne-chateaucreux', 'madrid', 'angers-saint-laud',
#        'metz', 'strasbourg', 'dunkerque', 'besancon-franche-comte',
#        'dijon-ville', 'grenoble', 'nice-ville', 'toulon', 'le-mans',
#        'quimper', 'st-malo', 'st-pierre-des-corps', 'tours', 'vannes',
#        'nancy', 'chambery-challes-les-eaux', 'marne-la-vallee', 'nimes',
#        'barcelona', 'geneve', 'italie', 'lausanne', 'brest', 'laval',
#        'poitiers', 'reims', 'perpignan', 'stuttgart', 'zurich'],
#       dtype=object)

# %% [markdown]
# ## Creating columns to match reg1

# %%
reg2['number_of_trains_actual'] = reg2['number_of_trains_scheduled'] - reg2['number_of_train_canceled']

# %%
reg2['percentage_trains_canceled'] = round(reg2['number_of_train_canceled']*100/reg2['number_of_trains_scheduled'], 2)

# %% [markdown]
# ### Creating matching reliability columns (testing on reg1 first)

# %%
reg1['test'] = round((reg1['number_of_trains_actual']-reg1['trains_late_at_destination'])/reg1['number_of_trains_actual']*100,1)
reg1.head()
# Out:
#       date  month  year              axis    origin destination  \
# 0  2014-01      1  2014    nord-normandie     paris   cherbourg
# 1  2014-01      1  2014    nord-normandie  le-havre       paris
# 2  2014-01      1  2014    nord-normandie  maubeuge       paris
# 3  2014-01      1  2014    nord-normandie      caen       paris
# 4  2014-01      1  2014  centre-sud-ouest   orleans       paris
#
#    number_of_trains_scheduled  number_of_trains_actual  \
# 0                       173.0                    172.0
# 1                       364.0                    360.0
# 2                       306.0                    305.0
# 3                       193.0                    193.0
# 4                       355.0                    354.0
#
#    number_of_train_canceled  trains_late_at_destination  reliability  \
# 0                       1.0                        14.0         91.9
# 1                       4.0                        33.0         90.8
# 2                       1.0                        18.0         94.1
# 3                       0.0                        20.0         89.6
# 4                       1.0                        40.0         88.7
#
#    number_of_trains_on_time_for_one_late_train             line  \
# 0                                         11.3  paris:cherbourg
# 1                                          9.9   le-havre:paris
# 2                                         15.9   maubeuge:paris
# 3                                          8.7       caen:paris
# 4                                          7.8    orleans:paris
#
#    percentage_trains_canceled  test
# 0                        0.58  91.9
# 1                        1.10  90.8
# 2                        0.33  94.1
# 3                        0.00  89.6
# 4                        0.28  88.7

# %%
reg2['reliability'] = round((reg2['number_of_trains_actual']-reg2['trains_late_at_destination'])/reg2['number_of_trains_actual']*100,1)

# %% [markdown]
# ### Creating line column

# %%
reg2['line'] = reg2['origin']+':'+reg2['destination']

# %% [markdown]
# ## Rearranging columns

# %%
reg1.columns
# Out:
# Index(['date', 'month', 'year', 'axis', 'origin', 'destination',
#        'number_of_trains_scheduled', 'number_of_trains_actual',
#        'number_of_train_canceled', 'trains_late_at_destination', 'reliability',
#        'number_of_trains_on_time_for_one_late_train', 'line',
#        'percentage_trains_canceled', 'test'],
#       dtype='object')

# %%
reg2.columns
# Out:
# Index(['date', 'month', 'year', 'axis', 'origin', 'destination',
#        'number_of_trains_scheduled', 'number_of_train_canceled',
#        'trains_late_at_destination', 'duration', 'number_of_trains_actual',
#        'percentage_trains_canceled', 'reliability', 'line'],
#       dtype='object')

# %%
reg1 = reg1[['date', 'month', 'year', 'axis', 'origin', 'destination',
       'number_of_trains_scheduled', 'number_of_train_canceled',
       'trains_late_at_destination', 'number_of_trains_actual',
       'percentage_trains_canceled', 'reliability', 'line']]

# %%
reg1['axis'] = 'Intercites'
reg1.head()
# Out:
#       date  month  year        axis    origin destination  \
# 0  2014-01      1  2014  Intercites     paris   cherbourg
# 1  2014-01      1  2014  Intercites  le-havre       paris
# 2  2014-01      1  2014  Intercites  maubeuge       paris
# 3  2014-01      1  2014  Intercites      caen       paris
# 4  2014-01      1  2014  Intercites   orleans       paris
#
#    number_of_trains_scheduled  number_of_train_canceled  \
# 0                       173.0                       1.0
# 1                       364.0                       4.0
# 2                       306.0                       1.0
# 3                       193.0                       0.0
# 4                       355.0                       1.0
#
#    trains_late_at_destination  number_of_trains_actual  \
# 0                        14.0                    172.0
# 1                        33.0                    360.0
# 2                        18.0                    305.0
# 3                        20.0                    193.0
# 4                        40.0                    354.0
#
#    percentage_trains_canceled  reliability             line
# 0                        0.58         91.9  paris:cherbourg
# 1                        1.10         90.8   le-havre:paris
# 2                        0.33         94.1   maubeuge:paris
# 3                        0.00         89.6       caen:paris
# 4                        0.28         88.7    orleans:paris

# %% [markdown]
# # Concatenating

# %%
reg = pd.concat([reg1, reg2[['date', 'month', 'year', 'axis', 'origin', 'destination',
       'number_of_trains_scheduled', 'number_of_train_canceled',
       'trains_late_at_destination', 'number_of_trains_actual',
       'percentage_trains_canceled', 'reliability', 'line']]], axis = 0)

# %%
reg.shape
# Out:
# (9075, 13)

# %% [markdown]
# ### Taking only the rows from each df with matching dates

# %%
reg = reg[(reg['year']>2017)&(reg['year']<2021)]

# %%
reg.shape
# Out:
# (5649, 13)

# %% [markdown]
# ## Dealing with nulls

# %%
reg.isna().sum()/len(reg)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af6684dace16> in <module>
# ----> 1 reg.isna().sum()/len(reg)*100
#
# NameError: name 'reg' is not defined

# %%
reg = reg[(reg['number_of_trains_scheduled'] !=0) & ~(reg['number_of_trains_scheduled'].isna()) & ~(reg['trains_late_at_destination'].isna())]

# %%
# I am choosing to get rid of all nans as they are in  my target colums and replacing number of trains canceled with mean gives negative reliability

# %% [markdown]
# ### Grouping by origin to see number of destinations and trains canceled and reliability

# %%
pd.set_option('display.max_rows', 76)
reg.groupby(['origin']).agg({'destination': pd.Series.nunique, 'number_of_train_canceled': np.mean, 'reliability': np.mean})
# Out:
#                                 destination  number_of_train_canceled  \
# origin
# aix-en-provence                           1                 12.000000
# albi                                      1                  0.625000
# amiens                                    1                  2.166667
# angers-saint-laud                         1                 18.527778
# angouleme                                 1                 12.194444
# annecy                                    1                  8.558824
# arras                                     1                 24.055556
# avignon                                   1                 16.000000
# barcelona                                 1                  1.828571
# bayonne                                   1                  2.545455
# bellegarde-(ain)                          1                  9.085714
# besancon-franche-comte                    1                  6.833333
# beziers                                   1                  0.700000
# bordeaux-st-jean                          4                 14.450000
# boulogne                                  1                  4.500000
# brest                                     1                 12.416667
# briancon                                  1                  0.642857
# brive                                     1                  3.400000
# caen                                      2                  2.625000
# chambery-challes-les-eaux                 1                 13.285714
# cherbourg                                 1                  3.416667
# clermont-ferrand                          2                  1.672131
# dijon-ville                               1                 14.194444
# douai                                     1                  9.722222
# dunkerque                                 1                 10.200000
# francfort                                 1                  5.941176
# geneve                                    1                  8.085714
# granville                                 1                  1.375000
# grenoble                                  1                  7.971429
# hendaye                                   1                  2.666667
# italie                                    1                  5.400000
# la-rochelle-ville                         1                  7.600000
# latour-de-carol                           1                  1.576923
# lausanne                                  1                  4.971429
# laval                                     1                  9.027778
# le-creusot-montceau-montchanin            1                  5.944444
# le-havre                                  1                  4.208333
# le-mans                                   1                 17.333333
# lille                                     3                 17.523364
# lyon                                      7                 16.995902
# macon-loche                               1                 10.750000
# madrid                                    1                  2.285714
# marne-la-vallee                           2                 13.585714
# marseille-st-charles                      7                 10.951111
# maubeuge                                  1                  2.250000
# metz                                      1                 11.805556
# montpellier                               2                 20.690141
# mulhouse-ville                            1                 10.222222
# nancy                                     1                 12.694444
# nantes                                    4                  7.212766
# nice-ville                                1                 10.085714
# nimes                                     1                 21.166667
# paris                                    66                 10.450919
# perpignan                                 1                 13.228571
# poitiers                                  1                 21.111111
# quimper                                   1                 11.527778
# reims                                     1                  7.971429
# rennes                                    2                 17.914634
# rouen-rive-droite                         1                  5.708333
# saint-etienne-chateaucreux                1                  3.121212
# st-malo                                   1                  3.142857
# st-pierre-des-corps                       1                 18.333333
# st-quentin                                1                  2.750000
# strasbourg                                2                 11.147059
# stuttgart                                 1                  3.727273
# toulon                                    1                 13.200000
# toulouse                                  3                  2.877049
# tourcoing                                 2                  1.125000
# tours                                     2                  3.983051
# trouville-deauville                       1                  1.708333
# valence-alixan                            1                 16.416667
# vannes                                    1                 13.027778
# zurich                                    1                  3.800000
#
#                                 reliability
# origin
# aix-en-provence                   88.727778
# albi                              90.675000
# amiens                            75.166667
# angers-saint-laud                 81.336111
# angouleme                         80.761111
# annecy                            80.729412
# arras                             74.966667
# avignon                           84.850000
# barcelona                         82.680000
# bayonne                           87.795455
# bellegarde-(ain)                  85.462857
# besancon-franche-comte            91.213889
# beziers                           90.753333
# bordeaux-st-jean                  82.628571
# boulogne                          81.275000
# brest                             90.488889
# briancon                          82.214286
# brive                             87.316667
# caen                              87.710417
# chambery-challes-les-eaux         75.385714
# cherbourg                         83.520833
# clermont-ferrand                  88.577049
# dijon-ville                       89.358333
# douai                             76.488889
# dunkerque                         88.551429
# francfort                         81.638235
# geneve                            87.634286
# granville                         91.512500
# grenoble                          90.557143
# hendaye                           75.050000
# italie                            69.380000
# la-rochelle-ville                 87.525714
# latour-de-carol                   85.750000
# lausanne                          89.142857
# laval                             81.186111
# le-creusot-montceau-montchanin    80.700000
# le-havre                          85.400000
# le-mans                           71.927778
# lille                             82.996262
# lyon                              80.205328
# macon-loche                       79.766667
# madrid                            77.314286
# marne-la-vallee                   83.197143
# marseille-st-charles              81.293333
# maubeuge                          85.158333
# metz                              80.094444
# montpellier                       83.569014
# mulhouse-ville                    88.733333
# nancy                             90.419444
# nantes                            85.743972
# nice-ville                        85.002857
# nimes                             80.436111
# paris                             85.995383
# perpignan                         83.602857
# poitiers                          77.661111
# quimper                           90.375000
# reims                             84.357143
# rennes                            84.959756
# rouen-rive-droite                 88.600000
# saint-etienne-chateaucreux        88.209091
# st-malo                           87.125714
# st-pierre-des-corps               74.038889
# st-quentin                        83.541667
# strasbourg                        83.773529
# stuttgart                         81.206061
# toulon                            85.402857
# toulouse                          84.753279
# tourcoing                         83.952500
# tours                             83.208475
# trouville-deauville               85.862500
# valence-alixan                    80.947222
# vannes                            84.036111
# zurich                            89.308571

# %% [markdown]
# # Relationship time (chi² contingency table)

# %% [markdown]
# H0 : there is no relationship between line and reliability
#
# H1 : there is one

# %%
# binning percentages to compare 2 categorical variables

# %%
bins = pd.cut(reg['reliability'],3)

# %%
reliability_crosstab = pd.crosstab(reg['line'],bins, margins=False)

# %%
st.chi2_contingency(reliability_crosstab)
# p-value is very close to 0 --> we reject H0 --> there is a relationship between line and reliability
# Out:
# (645.7284901793,
#  1.1208118592797027e-22,
#  330,
#  array([[1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.35458167e-01, 1.13908004e+00, 3.27254618e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.11553785e-01, 9.38065918e-01, 2.69503803e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.23505976e-01, 1.03857298e+00, 2.98379210e+01],
#         [1.91235060e-01, 1.60811300e+00, 4.62006519e+01],
#         [1.23505976e-01, 1.03857298e+00, 2.98379210e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.11553785e-01, 9.38065918e-01, 2.69503803e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.23505976e-01, 1.03857298e+00, 2.98379210e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.35458167e-01, 1.13908004e+00, 3.27254618e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.03585657e-01, 8.71061210e-01, 2.50253531e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.11553785e-01, 9.38065918e-01, 2.69503803e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.23505976e-01, 1.03857298e+00, 2.98379210e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [1.91235060e-01, 1.60811300e+00, 4.62006519e+01],
#         [1.27490040e-01, 1.07207534e+00, 3.08004346e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.96015936e-02, 8.37558855e-01, 2.40628396e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.35458167e-01, 1.13908004e+00, 3.27254618e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.91235060e-01, 1.60811300e+00, 4.62006519e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.11553785e-01, 9.38065918e-01, 2.69503803e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.23505976e-01, 1.03857298e+00, 2.98379210e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.03585657e-01, 8.71061210e-01, 2.50253531e+01],
#         [1.35458167e-01, 1.13908004e+00, 3.27254618e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.91235060e-01, 1.60811300e+00, 4.62006519e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.91235060e-01, 1.60811300e+00, 4.62006519e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.35458167e-01, 1.13908004e+00, 3.27254618e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.31474104e-01, 1.10557769e+00, 3.17629482e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [3.74501992e-01, 3.14922130e+00, 9.04762767e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.87250996e-01, 1.57461065e+00, 4.52381384e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.31474104e-01, 1.10557769e+00, 3.17629482e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [4.78087649e-02, 4.02028251e-01, 1.15501630e+01],
#         [1.27490040e-01, 1.07207534e+00, 3.08004346e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.31474104e-01, 1.10557769e+00, 3.17629482e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [1.11553785e-01, 9.38065918e-01, 2.69503803e+01],
#         [3.74501992e-01, 3.14922130e+00, 9.04762767e+01],
#         [1.19521912e-01, 1.00507063e+00, 2.88754075e+01],
#         [3.98406375e-02, 3.35023542e-01, 9.62513582e+00],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01],
#         [9.56175299e-02, 8.04056501e-01, 2.31003260e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.43426295e-01, 1.20608475e+00, 3.46504890e+01],
#         [1.39442231e-01, 1.17258240e+00, 3.36879754e+01]]))

# %%
bins2 = pd.cut(reg['percentage_trains_canceled'],5)

# %%
canceled_crosstab = pd.crosstab(reg['line'],bins2, margins=False)
st.chi2_contingency(canceled_crosstab)
# Out:
# (835.675583553591,
#  3.7214266668565058e-06,
#  660,
#  array([[3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.10076059e+01, 2.30894603e+00, 5.60304238e-01, 7.38862731e-02,
#          4.92575154e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.55356755e+01, 1.90148497e+00, 4.61427019e-01, 6.08475190e-02,
#          4.05650127e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [2.82716407e+01, 2.10521550e+00, 5.10865628e-01, 6.73668961e-02,
#          4.49112640e-02],
#         [4.37754437e+01, 3.25968852e+00, 7.91017747e-01, 1.04310033e-01,
#          6.95400217e-02],
#         [2.82716407e+01, 2.10521550e+00, 5.10865628e-01, 6.73668961e-02,
#          4.49112640e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.55356755e+01, 1.90148497e+00, 4.61427019e-01, 6.08475190e-02,
#          4.05650127e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [2.82716407e+01, 2.10521550e+00, 5.10865628e-01, 6.73668961e-02,
#          4.49112640e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.10076059e+01, 2.30894603e+00, 5.60304238e-01, 7.38862731e-02,
#          4.92575154e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.37116987e+01, 1.76566461e+00, 4.28467946e-01, 5.65012677e-02,
#          3.76675118e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.55356755e+01, 1.90148497e+00, 4.61427019e-01, 6.08475190e-02,
#          4.05650127e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.82716407e+01, 2.10521550e+00, 5.10865628e-01, 6.73668961e-02,
#          4.49112640e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [4.37754437e+01, 3.25968852e+00, 7.91017747e-01, 1.04310033e-01,
#          6.95400217e-02],
#         [2.91836291e+01, 2.17312568e+00, 5.27345165e-01, 6.95400217e-02,
#          4.63600145e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.27997102e+01, 1.69775444e+00, 4.11988410e-01, 5.43281420e-02,
#          3.62187613e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.10076059e+01, 2.30894603e+00, 5.60304238e-01, 7.38862731e-02,
#          4.92575154e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [4.37754437e+01, 3.25968852e+00, 7.91017747e-01, 1.04310033e-01,
#          6.95400217e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.55356755e+01, 1.90148497e+00, 4.61427019e-01, 6.08475190e-02,
#          4.05650127e-02],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [2.82716407e+01, 2.10521550e+00, 5.10865628e-01, 6.73668961e-02,
#          4.49112640e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.37116987e+01, 1.76566461e+00, 4.28467946e-01, 5.65012677e-02,
#          3.76675118e-02],
#         [3.10076059e+01, 2.30894603e+00, 5.60304238e-01, 7.38862731e-02,
#          4.92575154e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [4.37754437e+01, 3.25968852e+00, 7.91017747e-01, 1.04310033e-01,
#          6.95400217e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [4.37754437e+01, 3.25968852e+00, 7.91017747e-01, 1.04310033e-01,
#          6.95400217e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.10076059e+01, 2.30894603e+00, 5.60304238e-01, 7.38862731e-02,
#          4.92575154e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.00956175e+01, 2.24103586e+00, 5.43824701e-01, 7.17131474e-02,
#          4.78087649e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [8.57269105e+01, 6.38355668e+00, 1.54907642e+00, 2.04273814e-01,
#          1.36182543e-01],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [4.28634553e+01, 3.19177834e+00, 7.74538211e-01, 1.02136907e-01,
#          6.80912713e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.00956175e+01, 2.24103586e+00, 5.43824701e-01, 7.17131474e-02,
#          4.78087649e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [1.09438609e+01, 8.14922130e-01, 1.97754437e-01, 2.60775081e-02,
#          1.73850054e-02],
#         [2.91836291e+01, 2.17312568e+00, 5.27345165e-01, 6.95400217e-02,
#          4.63600145e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.00956175e+01, 2.24103586e+00, 5.43824701e-01, 7.17131474e-02,
#          4.78087649e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.55356755e+01, 1.90148497e+00, 4.61427019e-01, 6.08475190e-02,
#          4.05650127e-02],
#         [8.57269105e+01, 6.38355668e+00, 1.54907642e+00, 2.04273814e-01,
#          1.36182543e-01],
#         [2.73596523e+01, 2.03730532e+00, 4.94386092e-01, 6.51937704e-02,
#          4.34625136e-02],
#         [9.11988410e+00, 6.79101775e-01, 1.64795364e-01, 2.17312568e-02,
#          1.44875045e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02],
#         [2.18877218e+01, 1.62984426e+00, 3.95508874e-01, 5.21550163e-02,
#          3.47700109e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.28315828e+01, 2.44476639e+00, 5.93263310e-01, 7.82325244e-02,
#          5.21550163e-02],
#         [3.19195943e+01, 2.37685621e+00, 5.76783774e-01, 7.60593988e-02,
#          5.07062658e-02]]))

# %%
# same result between line and trains canceled

# %% [markdown]
# I would like to check the relation between distance and reliability but couldn't make it work so i'm checking with duration of traval from the high speed df

# %%
bins3 = pd.cut(reg2['reliability'],5)
duration_crosstab = pd.crosstab(reg2['duration'], bins3, margins=False)
st.chi2_contingency(duration_crosstab)
# Out:
# (2404.3600006798533,
#  1.0140974379329342e-49,
#  1456,
#  array([[1.63432074e-03, 3.47293156e-03, 1.20531154e-02, 1.99591420e-01,
#          7.83248212e-01],
#         [1.63432074e-02, 3.47293156e-02, 1.20531154e-01, 1.99591420e+00,
#          7.83248212e+00],
#         [1.09499489e-01, 2.32686415e-01, 8.07558733e-01, 1.33726251e+01,
#          5.24776302e+01],
#         ...,
#         [1.63432074e-03, 3.47293156e-03, 1.20531154e-02, 1.99591420e-01,
#          7.83248212e-01],
#         [6.53728294e-03, 1.38917263e-02, 4.82124617e-02, 7.98365679e-01,
#          3.13299285e+00],
#         [1.63432074e-03, 3.47293156e-03, 1.20531154e-02, 1.99591420e-01,
#          7.83248212e-01]]))

# %% [markdown]
# ## Trying to get distance

# %%
key = getpass.getpass() # get api key from:  https://opencagedata.com

# %%
# def find_distance(A,B):
#      
#     geocoder = OpenCageGeocode(key)
    
#     result_A = geocoder.geocode(A)
#     lat_A = result_A[0]['geometry']['lat']
#     lng_A = result_A[0]['geometry']['lng']
    
#     result_B = geocoder.geocode(B)
#     lat_B = result_B[0]['geometry']['lat']
#     lng_B = result_B[0]['geometry']['lng']  
    
#     return (geodesic((lat_A,lng_A), (lat_B,lng_B)).kilometers)

# find_distance('paris', 'Toulouse France')

# %%
# reg.pivot_table(index= ['origin', 'destination'], values = ['line'], aggfunc = ['nunique'])

# %%
# distance = reg[['origin', 'destination', 'line']].groupby('origin')
# distance = distance.sort_values(by = 'line')
# distance.head()

# %%
# def function1(row):
#     x,y = row.split(':')
#     z = find_distance(x, y)
#     return z




# reg['distance'] = reg['line'].apply(function1, axis=0)

# %%
# reg['distance'] = find_distance(reg['origin'], reg['destination'], axis = 1)

# %% [markdown]
# ## Exporting the file to mySQL

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/trains'
engine = create_engine(connection_string)
reg.to_sql('reg', con = engine, if_exists = 'replace')

# %% [markdown]
# ## Exporting the file (csv)

# %%
reg.to_csv(path_or_buf='./reg_clean.csv', index=False)
